# %% [markdown]
# <a href="https://colab.research.google.com/github/CALewis1955/sma-zoomcamp-2024/blob/main/hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTS
import numpy as np
import pandas as pd

#Fin Data Sources
import yfinance as yf
import pandas_datareader as pdr

#Data viz
import plotly.graph_objs as go
import plotly.express as px

import time
from datetime import date

# %%
end = date.today()
print(f'Year = {end.year}; month= {end.month}; day={end.day}')

start = date(year=end.year-70, month=end.month, day=end.day)
print(f'Period for indexes: {start} to {end} ')
# Out:
# Year = 2024; month= 4; day=18
# Period for indexes: 1954-04-18 to 2024-04-18

# %% [markdown]
# **GDP**

# %%
gdp = pdr.DataReader("GDPC1", "fred", start=start)

# %%
gdp.tail(12)
# Out:
#                 GDPC1
# DATE
# 2021-01-01  20990.541
# 2021-04-01  21309.544
# 2021-07-01  21483.083
# 2021-10-01  21847.602
# 2022-01-01  21738.871
# 2022-04-01  21708.160
# 2022-07-01  21851.134
# 2022-10-01  21989.981
# 2023-01-01  22112.329
# 2023-04-01  22225.350
# 2023-07-01  22490.692
# 2023-10-01  22679.255

# %%
gdp['GDPC1']['2023-10-01']
# Out:
# 22679.255

# %%
gdp['GDPC1'].shift(4).tail()
# Out:
# DATE
# 2022-10-01    21847.602
# 2023-01-01    21738.871
# 2023-04-01    21708.160
# 2023-07-01    21851.134
# 2023-10-01    21989.981
# Name: GDPC1, dtype: float64

# %%
gdp['us_yoy'] = (gdp['GDPC1']/gdp['GDPC1'].shift(4)) - 1

# %%
(gdp
.assign(YOY = gdp['GDPC1']/gdp['GDPC1'].shift(4) - 1))
# Out:
#                 GDPC1    us_yoy       YOY
# DATE
# 1954-07-01   2880.482       NaN       NaN
# 1954-10-01   2936.852       NaN       NaN
# 1955-01-01   3020.746       NaN       NaN
# 1955-04-01   3069.910       NaN       NaN
# 1955-07-01   3111.379  0.080159  0.080159
# ...               ...       ...       ...
# 2022-10-01  21989.981  0.006517  0.006517
# 2023-01-01  22112.329  0.017179  0.017179
# 2023-04-01  22225.350  0.023825  0.023825
# 2023-07-01  22490.692  0.029269  0.029269
# 2023-10-01  22679.255  0.031345  0.031345
#
# [278 rows x 3 columns]

# %%
gdp.tail(4)
# Out:
#                 GDPC1    us_yoy
# DATE
# 2023-01-01  22112.329  0.017179
# 2023-04-01  22225.350  0.023825
# 2023-07-01  22490.692  0.029269
# 2023-10-01  22679.255  0.031345

# %%
gdp = (gdp
.assign(YOY = gdp['GDPC1']/gdp['GDPC1'].shift(4) - 1))
gdp.tail(4)
# Out:
#                 GDPC1    us_yoy       YOY
# DATE
# 2023-01-01  22112.329  0.017179  0.017179
# 2023-04-01  22225.350  0.023825  0.023825
# 2023-07-01  22490.692  0.029269  0.029269
# 2023-10-01  22679.255  0.031345  0.031345

# %%
ans = gdp['us_yoy'].tail(4).mean()

# %%
print((ans * 100).round(2))
# Out:
# 2.54

# %%
item = gdp.YOY.loc['2023-01-01']

# %%
print(item)
# Out:
# 0.017179273017444263

# %% [markdown]
# **TREASURY YIELDS**

# %%
# https://fred.stlouisfed.org/series/DGS10
dgs10 = pdr.DataReader("DGS10", "fred", start=start)
dgs2 = pdr.DataReader("DGS2", "fred", start=start)
dgs10.tail(3)
dgs2.tail(3)
# Out:
#             DGS2
# DATE
# 2024-04-12  4.88
# 2024-04-15  4.93
# 2024-04-16  4.97

# %%
dgs10.tail(3)
# Out:
#             DGS10
# DATE
# 2024-04-12   4.50
# 2024-04-15   4.63
# 2024-04-16   4.67

# %%
dgs = dgs10.join(dgs2)

# %%
dgs.tail(4)
# Out:
#             DGS10  DGS2
# DATE
# 2024-04-11   4.56  4.93
# 2024-04-12   4.50  4.88
# 2024-04-15   4.63  4.93
# 2024-04-16   4.67  4.97

# %%
dgs['spread'] = dgs['DGS10'] - dgs['DGS2']
dgs.tail(4)
# Out:
#             DGS10  DGS2  spread
# DATE
# 2024-04-11   4.56  4.93   -0.37
# 2024-04-12   4.50  4.88   -0.38
# 2024-04-15   4.63  4.93   -0.30
# 2024-04-16   4.67  4.97   -0.30

# %%
dgs['spread']['2024-04-10']
# Out:
# -0.41999999999999993

# %%
dgs['spread'].tail(6335)
# Out:
# DATE
# 2000-01-05    0.24
# 2000-01-06    0.22
# 2000-01-07    0.21
# 2000-01-10    0.19
# 2000-01-11    0.22
#               ...
# 2024-04-10   -0.42
# 2024-04-11   -0.37
# 2024-04-12   -0.38
# 2024-04-15   -0.30
# 2024-04-16   -0.30
# Name: spread, Length: 6335, dtype: float64

# %%
min = dgs['spread'].tail(6335).min()

# %%
print(min)
# Out:
# -1.0800000000000005

# %%
post_2000 = dgs[dgs.index >= '2000-01-01']

# %%
post_2000.head(3)
# Out:
#             DGS10  DGS2  spread
# DATE
# 2000-01-03   6.58  6.38    0.20
# 2000-01-04   6.49  6.30    0.19
# 2000-01-05   6.62  6.38    0.24

# %%
min = post_2000['spread'].min()

# %%
print(min)
# Out:
# -1.0800000000000005

# %% [markdown]
# *Another way to reference a period of time*

# %%
post = dgs.loc['2000':]

# %%
post.head(3)
# Out:
#             DGS10  DGS2  spread
# DATE
# 2000-01-03   6.58  6.38    0.20
# 2000-01-04   6.49  6.30    0.19
# 2000-01-05   6.62  6.38    0.24

# %% [markdown]
# **INDEX**

# %%
# delayed 15 min : https://finance.yahoo.com/quote/%5ESPX/
# S&P 500 INDEX : Chicago Options - Chicago Options Delayed Price. Currency in USD
snp500_daily = yf.download(tickers = "^SPX",
                     period = "max",
                     interval = "1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
snp500_daily.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-04-11  5172.950195  5211.779785  5138.770020  5199.060059  5199.060059
# 2024-04-12  5171.509766  5175.029785  5107.939941  5123.410156  5123.410156
# 2024-04-15  5149.669922  5168.430176  5052.470215  5061.819824  5061.819824
# 2024-04-16  5064.589844  5079.839844  5039.830078  5051.410156  5051.410156
# 2024-04-17  5068.970215  5077.959961  5007.250000  5022.209961  5022.209961
#
#                 Volume
# Date
# 2024-04-11  3509380000
# 2024-04-12  3963220000
# 2024-04-15  3950210000
# 2024-04-16  4006200000
# 2024-04-17  3596130000

# %%
# delayed 15 min : https://finance.yahoo.com/quote/%5ESPX/
# S&P 500 INDEX : Chicago Options - Chicago Options Delayed Price. Currency in USD
ipc_mex_daily = yf.download(tickers = "^MXX",
                     period = "max",
                     interval = "1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
snp500_daily.Close.tail()
# Out:
# Date
# 2024-04-11    5199.060059
# 2024-04-12    5123.410156
# 2024-04-15    5061.819824
# 2024-04-16    5051.410156
# 2024-04-17    5022.209961
# Name: Close, dtype: float64

# %%
snp500_daily.Close[snp500_daily.index == '2024-04-09']
# Out:
# Date
# 2024-04-09    5209.910156
# Name: Close, dtype: float64

# %%
snp500_daily.Close[snp500_daily.index == '2024-04-09']['2024-04-09']
# Out:
# 5209.91015625

# %%
snp_growth_rate = (snp500_daily.Close[snp500_daily.index == '2024-04-09']['2024-04-09']/snp500_daily.Close[snp500_daily.index == '2019-04-09']['2019-04-09']) - 1

# %%
print((snp_growth_rate * 100).round(2) )
# Out:
# 81.01

# %%
ipc_growth_rate = (ipc_mex_daily.Close[ipc_mex_daily.index == '2024-04-09']['2024-04-09']/ipc_mex_daily.Close[ipc_mex_daily.index == '2019-04-09']['2019-04-09']) - 1

# %%
print((ipc_growth_rate * 100).round(2))
# Out:
# 27.51

# %% [markdown]
# Question 4. [Stocks OHLCV] 52-weeks range ratio (2023) for the selected stocks
# Find the largest range ratio [=(max-min)/max] of Adj.Close prices in 2023
#
# Download the 2023 daily OHLCV data on Yahoo Finance for top5 stocks on earnings (https://companiesmarketcap.com/most-profitable-companies/): 2222.SR,BRK-B, AAPL, MSFT, GOOG, JPM.
#
# Here is the example data you should see in Pandas for "2222.SR": https://finance.yahoo.com/quote/2222.SR/history
#
# Calculate maximum-minimim "Adj.Close" price for each stock and divide it by the maximum "Adj.Close" value. Round the result to two decimal places (e.g. 0.1575 will be 0.16)
#
# (Additional: why this may be important for your research?)

# %%
# https://finance.yahoo.com/quote/VOO?.tsrc=fin-srch
brkb = yf.download("BRK-B", start = '2023-01-01', end = '2023-12-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
brkb.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-22  356.500000  358.260010  355.410004  356.470001  356.470001
# 2023-12-26  356.899994  357.769989  356.079987  356.829987  356.829987
# 2023-12-27  355.929993  357.079987  355.500000  356.950012  356.950012
# 2023-12-28  357.480011  358.679993  356.730011  357.570007  357.570007
# 2023-12-29  357.559998  357.859985  355.309998  356.660004  356.660004
#
#              Volume
# Date
# 2023-12-22  2332200
# 2023-12-26  1964400
# 2023-12-27  2478500
# 2023-12-28  2740600
# 2023-12-29  3269400

# %%
min = brkb['Adj Close'].min()

# %%
max = brkb['Adj Close'].max()

# %%
range = (max - min)/max
print(range)
# Out:
# 0.20775750091289963

# %%
aapl = yf.download("AAPL", start = '2023-01-01', end = '2023-12-31')
aapl.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.353287
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.803986
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.903839
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.333298
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.284637
#
#               Volume
# Date
# 2023-12-22  37122800
# 2023-12-26  28919300
# 2023-12-27  48087700
# 2023-12-28  34049900
# 2023-12-29  42628800

# %%
min = aapl['Adj Close'].min()
max = aapl['Adj Close'].max()
range = (max - min)/max
print(range)
# Out:
# 0.37244419224463476

# %%
msft = yf.download("MSFT", start = '2023-01-01', end = '2023-12-31')
msft.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-22  373.679993  375.179993  372.709991  374.579987  373.888580
# 2023-12-26  375.000000  376.940002  373.500000  374.660004  373.968445
# 2023-12-27  373.690002  375.059998  372.809998  374.070007  373.379547
# 2023-12-28  375.369995  376.459991  374.160004  375.279999  374.587280
# 2023-12-29  376.000000  377.160004  373.480011  376.040009  375.345886
#
#               Volume
# Date
# 2023-12-22  17091100
# 2023-12-26  12673100
# 2023-12-27  14905400
# 2023-12-28  14327000
# 2023-12-29  18723000

# %%
min = msft['Adj Close'].min()
max = msft['Adj Close'].max()
range = (max - min)/max
print(range)
# Out:
# 0.4242066515530231

# %%
goog = yf.download("GOOG", start = '2023-01-01', end = '2023-12-31')
goog.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-22  142.130005  143.250000  142.054993  142.720001  142.720001
# 2023-12-26  142.979996  143.945007  142.500000  142.820007  142.820007
# 2023-12-27  142.830002  143.320007  141.050995  141.440002  141.440002
# 2023-12-28  141.850006  142.270004  140.828003  141.279999  141.279999
# 2023-12-29  140.679993  141.434998  139.899994  140.929993  140.929993
#
#               Volume
# Date
# 2023-12-22  18494700
# 2023-12-26  11170100
# 2023-12-27  17288400
# 2023-12-28  12192500
# 2023-12-29  14872700

# %%
min = goog['Adj Close'].min()
max = goog['Adj Close'].max()
range = (max - min)/max
print(range)
# Out:
# 0.3924520921912013

# %%
jpm = yf.download("JPM", start = '2023-01-01', end = '2023-12-31')
jpm.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-22  167.500000  168.229996  167.229996  167.399994  165.409210
# 2023-12-26  167.460007  168.770004  167.179993  168.389999  166.387451
# 2023-12-27  167.839996  169.470001  167.580002  169.399994  167.385437
# 2023-12-28  169.350006  170.660004  169.000000  170.300003  168.274750
# 2023-12-29  170.000000  170.690002  169.630005  170.100006  168.077133
#
#              Volume
# Date
# 2023-12-22  6574900
# 2023-12-26  4683600
# 2023-12-27  6428600
# 2023-12-28  6320100
# 2023-12-29  6431800

# %%
min = jpm['Adj Close'].min()
max = jpm['Adj Close'].max()
range = (max - min)/max
print(range)
# Out:
# 0.28249929679343244

# %% [markdown]
# **STOCKS DIVIDEND YIELD**

# %% [markdown]
# Question 5. [Stocks] Dividend Yield
# Find the largest dividend yield for the same set of stocks
#
# Use the same list of companies (2222.SR,BRK-B, AAPL, MSFT, GOOG, JPM) and download all dividends paid in 2023. You can use get_actions() method or .dividends field in yfinance library (https://github.com/ranaroussi/yfinance?tab=readme-ov-file#quick-start)
#
# Sum up all dividends paid in 2023 per company and divide each value by the closing price (Adj.Close) at the last trading day of the year.
#
# Find the maximm value in % and round to 1 digit after the decimal point. (E.g., if you obtained $1.25 dividends paid and the end year stock price is $100, the dividend yield is 1.25% -- and your answer should be equal to 1.3)

# %%
brkb_sym = yf.Ticker('BRK-B').get_actions()

# %%
print(brkb_sym)
# Out:
#                            Dividends  Stock Splits
# Date
# 2010-01-21 00:00:00-05:00        0.0          50.0

# %%
brkb_divs = (brkb_sym.Dividends[(brkb_sym.index >= '2023-01-01') & (brkb_sym.index <= '2023-12-31')])
print(brkb_divs)
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
aapl_sym = yf.Ticker('AAPL').get_actions()

# %%
print(aapl_sym.Dividends)
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-06-16 00:00:00-04:00    0.000000
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
#                                ...
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# 2023-08-11 00:00:00-04:00    0.240000
# 2023-11-10 00:00:00-05:00    0.240000
# 2024-02-09 00:00:00-05:00    0.240000
# Name: Dividends, Length: 87, dtype: float64

# %%
aapl_divs = (aapl_sym.Dividends[(aapl_sym.index >= '2023-01-01') & (aapl_sym.index <= '2023-12-31')])
print(aapl_divs)
# Out:
# Date
# 2023-02-10 00:00:00-05:00    0.23
# 2023-05-12 00:00:00-04:00    0.24
# 2023-08-11 00:00:00-04:00    0.24
# 2023-11-10 00:00:00-05:00    0.24
# Name: Dividends, dtype: float64

# %%
aapl_div_yield = aapl_divs.sum()/aapl['Adj Close']['2023-12-29']

# %%
print(aapl_div_yield)
# Out:
# 0.004940592304162832

# %%
msft_sym = yf.Ticker('MSFT').get_actions()

# %%
msft_divs = (msft_sym.Dividends[(msft_sym.index >= '2023-01-01') & (msft_sym.index <= '2023-12-31')])
print(msft_divs)
# Out:
# Date
# 2023-02-15 00:00:00-05:00    0.68
# 2023-05-17 00:00:00-04:00    0.68
# 2023-08-16 00:00:00-04:00    0.68
# 2023-11-15 00:00:00-05:00    0.75
# Name: Dividends, dtype: float64

# %%
msft_div_yield = msft_divs.sum()/aapl['Adj Close']['2023-12-29']

# %%
print(msft_div_yield)
# Out:
# 0.014509739503804527

# %%
goog_sym = yf.Ticker('GOOG').get_actions()

# %%
goog_divs = (goog_sym.Dividends[(goog_sym.index >= '2023-01-01') & (goog_sym.index <= '2023-12-31')])
print(goog_divs)
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
jpm_sym = yf.Ticker('JPM').get_actions()

# %%
jpm_divs = (jpm_sym.Dividends[(jpm_sym.index >= '2023-01-01') & (jpm_sym.index <= '2023-12-31')])
print(jpm_divs)
# Out:
# Date
# 2023-01-05 00:00:00-05:00    1.00
# 2023-04-05 00:00:00-04:00    1.00
# 2023-07-05 00:00:00-04:00    1.00
# 2023-10-05 00:00:00-04:00    1.05
# Name: Dividends, dtype: float64

# %%
jpm_div_yield = jpm_divs.sum()/jpm['Adj Close']['2023-12-29']

# %%
print(jpm_div_yield)
# Out:
# 0.024096079718909574

# %% [markdown]
# Question 6. [Exploratory] Investigate new metrics
# Free text answer
#
# Download and explore a few additional metrics or time series that might be valuable for your project and write down why (briefly).

# %% [markdown]
# A few metrics that might be valuable are momentum indicators, such as rate of change or a relative strength index.  These indicators are technical signals of when stock prices could move, but they are prone to whipsaws.

# %% [markdown]
# Question 7. [Exploratory] Time-driven strategy description around earnings releases
# Free text answer
#
# Explore earning dates for the whole month of April - e.g. using YahooFinance earnings calendar (https://finance.yahoo.com/calendar/earnings?from=2024-04-21&to=2024-04-27&day=2024-04-23). Compare with the previous closed earnings (e.g., recent dates with full data https://finance.yahoo.com/calendar/earnings?from=2024-04-07&to=2024-04-13&day=2024-04-08).
#
# Describe an analytical strategy/idea (you're not required to implement it) to select a subset companies of interest based on the future events data.

# %% [markdown]
# Attempt to identify companies with accelerating earnings growth and increasing free cash flow.  Buy these.  Attempt to identify companies that "manufacture" earnings by manipulating the financials but lack the free cash flow to sustain them.
